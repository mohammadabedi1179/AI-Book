# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 .
# drwxr-xr-x 1 root root 4096 Dec 25 12:06 ..
# drwxr-xr-x 4 root root 4096 Dec 20 20:18 .config
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 sample_data

# %%
# !cd drive/MyDrive/Documents

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Dec 25 12:09 .
# drwxr-xr-x 1 root root 4096 Dec 25 12:06 ..
# drwxr-xr-x 4 root root 4096 Dec 20 20:18 .config
# drwx------ 5 root root 4096 Dec 25 12:09 drive
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 sample_data

# %%
# %cd drive/MyDrive/Documents
# Out:
# /content/drive/MyDrive/Documents

# %%
# !ls -la
# Out:
# total 8
# drwx------ 2 root root 4096 Aug 18 14:25 'AI book'
# drwx------ 2 root root 4096 Aug 28 18:00  Internship_cast

# %%
# %cd 'AI book'
# Out:
# /content/drive/MyDrive/Documents/AI book

# %%
# !git init AI_Book
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Documents/AI book/AI_Book/.git/

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Documents/AI book/.git/

# %%
# !git add .
# !git status
